# %%
# Install pyspark and findspark
# !pip install --ignore-install -q pyspark
# Install findspark library
# !pip install --ignore-install -q findspark

# %%
# Import findspark
import findspark
findspark.init()

# %%
import sys
sys.version_info
print(sys.version)
# Out:
# 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 1. Set up spark context and SparkSession

# %%
# Import necessary libraries
from pyspark.sql import SparkSession
from pyspark.ml import Pipeline
from pyspark.ml.feature import CountVectorizer,StringIndexer, RegexTokenizer,StopWordsRemover
from pyspark.ml.feature import HashingTF, IDF
from pyspark.sql.functions import col, udf,regexp_replace,isnull
from pyspark.sql.types import StringType,IntegerType
from pyspark.ml.classification import NaiveBayes, RandomForestClassifier, LogisticRegression, DecisionTreeClassifier, GBTClassifier
from pyspark.ml.evaluation import MulticlassClassificationEvaluator, BinaryClassificationEvaluator
from pyspark.ml.tuning import ParamGridBuilder, CrossValidator
from pyspark.sql.functions import rand

# %%
from pyspark.sql import SparkSession

spark = SparkSession \
    .builder \
    .appName("PySpark-TextClassifier") \
    .getOrCreate()

# %% [markdown]
# ### 2. Load dataset

# %%
data = spark.read.csv("/content/drive/MyDrive/Colab Notebooks/rSingapore_sample_1100comment_with_submission.csv", header=True, inferSchema=True)

# %%
# randomize labels
data = data.dropna()
data = data.withColumn("label", (rand() <= 0.2).cast("int"))
data.show(5)
# Out:
# +-------+-------------------+--------------------+-------+------------+--------------------+--------------------+-----+
# |     id|                 dt|          submission|upvotes|upvote_ratio|              author|                body|label|
# +-------+-------------------+--------------------+-------+------------+--------------------+--------------------+-----+
# |kq2e83o|2024-02-12 10:42:02|Medicine in Malay...|    162|        0.87|           jespep831|Brunei is like Ju...|    0|
# |kq2e83o|2024-02-12 10:42:02|Medicine in Malay...|    162|        0.87|           jespep831|Brunei is like Ju...|    0|
# |kq2e8y7|2024-02-12 10:42:20|'Disgusting and u...|     31|        0.83|       TheLastHarlow|😭 it doesn’t hel...|    0|
# |kq2e8zs|2024-02-12 10:42:21|Commentary: Low i...|     30|         0.9|Budget-Juggernaut-68|It's a tax for an...|    0|
# |kq2e9m6|2024-02-12 10:42:35|Last kampung hous...|     86|        0.94|             0bxcura|"The government "...|    0|
# +-------+-------------------+--------------------+-------+------------+--------------------+--------------------+-----+
# only showing top 5 rows

# %% [markdown]
# ### 3. Text Processing and Modelling

# %%
# regular expression tokenizer
regexTokenizer = RegexTokenizer(inputCol="body", outputCol="words", pattern="\\W")
# stop words
add_stopwords = ["is","like","and","the"]
stopwordsRemover = StopWordsRemover(inputCol="words", outputCol="filtered").setStopWords(add_stopwords)
# bag of words count
countVectors = CountVectorizer(inputCol="filtered", outputCol="features")

# %%
hashingTF = HashingTF(inputCol="filtered", outputCol="rawFeatures", numFeatures=10000)
idf = IDF(inputCol="rawFeatures", outputCol="features", minDocFreq=5) #minDocFreq: remove sparse terms

# %%
# pipeline = Pipeline(stages=[regexTokenizer, stopwordsRemover,countVectors])
pipeline = Pipeline(stages=[regexTokenizer, stopwordsRemover, hashingTF, idf])
pipelineFit = pipeline.fit(data)
dataset = pipelineFit.transform(data)
dataset.show(5)
# Out:
# +-------+-------------------+--------------------+-------+------------+--------------------+--------------------+-----+--------------------+--------------------+--------------------+--------------------+
# |     id|                 dt|          submission|upvotes|upvote_ratio|              author|                body|label|               words|            filtered|         rawFeatures|            features|
# +-------+-------------------+--------------------+-------+------------+--------------------+--------------------+-----+--------------------+--------------------+--------------------+--------------------+
# |kq2e83o|2024-02-12 10:42:02|Medicine in Malay...|    162|        0.87|           jespep831|Brunei is like Ju...|    0|[brunei, is, like...|[brunei, jurassic...|(10000,[341,820,3...|(10000,[341,820,3...|
# |kq2e83o|2024-02-12 10:42:02|Medicine in Malay...|    162|        0.87|           jespep831|Brunei is like Ju...|    0|[brunei, is, like...|[brunei, jurassic...|(10000,[341,820,3...|(10000,[341,820,3...|
# |kq2e8y7|2024-02-12 10:42:20|'Disgusting and u...|     31|        0.83|       TheLastHarlow|😭 it doesn’t hel...|    0|[it, doesn, t, he...|[it, doesn, t, he...|(10000,[488,1263,...|(10000,[488,1263,...|
# |kq2e8zs|2024-02-12 10:42:21|Commentary: Low i...|     30|         0.9|Budget-Juggernaut-68|It's a tax for an...|    0|[it, s, a, tax, f...|[it, s, a, tax, f...|(10000,[971,3479,...|(10000,[971,3479,...|
# |kq2e9m6|2024-02-12 10:42:35|Last kampung hous...|     86|        0.94|             0bxcura|"The government "...|    0|[the, government,...|[government, acqu...|(10000,[307,1617,...|(10000,[307,1617,...|
# +-------+-------------------+--------------------+-------+------------+--------------------+--------------------+-----+--------------------+--------------------+--------------------+--------------------+
# only showing top 5 rows

# %%
# Train test split
(training_data, testing_data) = dataset.randomSplit([0.8, 0.2], seed=123)

# %%
# Logistic Regression
lr = LogisticRegression(maxIter=5, regParam=0.3, elasticNetParam=0)
lrModel = lr.fit(training_data)
predictions = lrModel.transform(testing_data)
predictions.filter(predictions['prediction'] == 1) \
    .select("body","label","prediction") \
    .orderBy("probability", ascending=False) \
    .show(n = 20, truncate = 30)
# Out:
# +------------------------------+-----+----------+
# |                          body|label|prediction|
# +------------------------------+-----+----------+
# |You should write in to SBS ...|    1|       1.0|
# |Regardless of one's view of...|    0|       1.0|
# |From what I hear, I'm sligh...|    0|       1.0|
# |Pretty sure this is already...|    1|       1.0|
# +------------------------------+-----+----------+

# %%
# DecisionTreeClassifier
dt = DecisionTreeClassifier(labelCol="label", featuresCol="features", maxDepth=5, minInfoGain=0.001, impurity="entropy")
dtModel = dt.fit(training_data)
predictions = dtModel.transform(testing_data)


predictions.filter(predictions['prediction'] == 1) \
    .select("body","label","prediction") \
    .orderBy("probability", ascending=False) \
    .show(n = 20, truncate = 30)
# Out:
# +------------------------------+-----+----------+
# |                          body|label|prediction|
# +------------------------------+-----+----------+
# |>Our gov already turning to...|    0|       1.0|
# |How about you don't do high...|    1|       1.0|
# |After all the scams going o...|    0|       1.0|
# |Japan - went recently. I fo...|    0|       1.0|
# +------------------------------+-----+----------+

# %%
# RFClassifier

rf = RandomForestClassifier(labelCol="label", \
                            featuresCol="features", \
                            numTrees = 100, \
                            maxDepth = 4, \
                            maxBins = 32)
rfModel = rf.fit(training_data)
predictions = rfModel.transform(testing_data)

predictions.filter(predictions['prediction'] == 1) \
    .select("body","label","prediction") \
    .orderBy("probability", ascending=False) \
    .show(n = 20, truncate = 30)
# Out:
# +----+-----+----------+
# |body|label|prediction|
# +----+-----+----------+
# +----+-----+----------+

# %%
# GBT Classifier
gbt = GBTClassifier(labelCol="label", \
                            featuresCol="features", \
                            maxIter = 5)
gbtModel = gbt.fit(training_data)
predictions = gbtModel.transform(testing_data)

predictions.filter(predictions['prediction'] == 1) \
    .select("body","label","prediction") \
    .orderBy("probability", ascending=False) \
    .show(n = 20, truncate = 30)
# Out:
# +------------------------------+-----+----------+
# |                          body|label|prediction|
# +------------------------------+-----+----------+
# |Some people are absolute cu...|    0|       1.0|
# |After all the scams going o...|    0|       1.0|
# |Max grant 80k TODAY. I'm ta...|    0|       1.0|
# |How about you don't do high...|    1|       1.0|
# |They do have dedicated gate...|    1|       1.0|
# |I think main issue with nuc...|    0|       1.0|
# |>Our gov already turning to...|    0|       1.0|
# |I see the future in small, ...|    0|       1.0|
# |From the dimension of natio...|    0|       1.0|
# +------------------------------+-----+----------+

# %% [markdown]
# ### 4. Evaluation

# %%
evaluator = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction", metricName="accuracy")

# %%
# ParamGrid
paramGrid = (ParamGridBuilder()
             .addGrid(lr.regParam, [0.1, 0.3, 0.5]) # regularization parameter
             .addGrid(lr.elasticNetParam, [0.0, 0.1, 0.2]) # Elastic Net Parameter (Ridge = 0)
#            .addGrid(model.maxIter, [10, 20, 50]) #Number of iterations
#            .addGrid(idf.numFeatures, [10, 100, 1000]) # Number of features
             .build())
# n-fold CrossValidator
cv = CrossValidator(estimator=rf, \
                    estimatorParamMaps=paramGrid, \
                    evaluator=evaluator, \
                    numFolds=4)
cvModel = cv.fit(training_data)

predictions = cvModel.transform(testing_data)

# %%
accuracy = evaluator.evaluate(predictions)

print(f"Test Accuracy: {accuracy:.2f}")
# Out:
# Test Accuracy: 0.79

# %% [markdown]
# 5. Visualize the Decision Tree

# %%
print(rfModel.toDebugString)
# Out:
# RandomForestClassificationModel: uid=RandomForestClassifier_98ad0ea3ebe1, numTrees=100, numClasses=2, numFeatures=10000
#   Tree 0 (weight 1.0):
#     If (feature 3996 <= 2.3093572055479243)
#      If (feature 594 <= 1.9192779267731368)
#       If (feature 6501 <= 2.4096925532789997)
#        If (feature 8501 <= 2.612425107333082)
#         Predict: 0.0
#        Else (feature 8501 > 2.612425107333082)
#         Predict: 1.0
#       Else (feature 6501 > 2.4096925532789997)
#        Predict: 1.0
#      Else (feature 594 > 1.9192779267731368)
#       If (feature 3921 <= 1.376964903426452)
#        If (feature 5741 <= 1.3172915246101689)
#         Predict: 0.0
#        Else (feature 5741 > 1.3172915246101689)
#         Predict: 1.0
#       Else (feature 3921 > 1.376964903426452)
#        Predict: 1.0
#     Else (feature 3996 > 2.3093572055479243)
#      Predict: 0.0
#   Tree 1 (weight 1.0):
#     If (feature 5169 <= 2.122010480827219)
#      If (feature 9147 <= 2.225830163216341)
#       If (feature 9797 <= 2.535349767419453)
#        If (feature 696 <= 2.535349767419453)
#         Predict: 0.0
#        Else (feature 696 > 2.535349767419453)
#         Predict: 1.0
#       Else (feature 9797 > 2.535349767419453)
#        Predict: 1.0
#      Else (feature 9147 > 2.225830163216341)
#       Predict: 0.0
#     Else (feature 5169 > 2.122010480827219)
#      Predict: 1.0
#   Tree 2 (weight 1.0):
#     If (feature 488 <= 3.6498002520873527)
#      If (feature 764 <= 2.2658515170531093)
#       If (feature 4293 <= 2.612425107333082)
#        If (feature 6287 <= 1.9192779267731368)
#         Predict: 0.0
#        Else (feature 6287 > 1.9192779267731368)
#         Predict: 1.0
#       Else (feature 4293 > 2.612425107333082)
#        Predict: 1.0
#      Else (feature 764 > 2.2658515170531093)
#       If (feature 6369 <= 1.4447376494245638)
#        Predict: 1.0
#       Else (feature 6369 > 1.4447376494245638)
#        Predict: 0.0
#     Else (feature 488 > 3.6498002520873527)
#      Predict: 0.0
#   Tree 3 (weight 1.0):
#     If (feature 1623 <= 6.56632853141844)
#      If (feature 9686 <= 2.3874894996192246)
#       If (feature 2137 <= 2.1542797413960044)
#        If (feature 8786 <= 2.612425107333082)
#         Predict: 0.0
#        Else (feature 8786 > 2.612425107333082)
#         Predict: 1.0
#       Else (feature 2137 > 2.1542797413960044)
#        Predict: 0.0
#      Else (feature 9686 > 2.3874894996192246)
#       If (feature 4032 <= 1.5939841437025621)
#        If (feature 9578 <= 2.4685840711071916)
#         Predict: 0.0
#        Else (feature 9578 > 2.4685840711071916)
#         Predict: 1.0
#       Else (feature 4032 > 1.5939841437025621)
#        Predict: 0.0
#     Else (feature 1623 > 6.56632853141844)
#      Predict: 1.0
#   Tree 4 (weight 1.0):
#     If (feature 5169 <= 2.122010480827219)
#      If (feature 6501 <= 2.4096925532789997)
#       If (feature 4338 <= 7.555822218868055)
#        If (feature 6936 <= 7.837275321999246)
#         Predict: 0.0
#        Else (feature 6936 > 7.837275321999246)
#         Predict: 1.0
#       Else (feature 4338 > 7.555822218868055)
#        Predict: 1.0
#      Else (feature 6501 > 2.4096925532789997)
#       If (feature 5133 <= 1.5939841437025621)
#        Predict: 0.0
#       Else (feature 5133 > 1.5939841437025621)
#        Predict: 1.0
#     Else (feature 5169 > 2.122010480827219)
#      Predict: 1.0
#   Tree 5 (weight 1.0):
#     If (feature 8092 <= 2.4096925532789997)
#      If (feature 6168 <= 1.7306308112024027)
#       Predict: 0.0
#      Else (feature 6168 > 1.7306308112024027)
#       If (feature 9928 <= 2.4685840711071916)
#        If (feature 7650 <= 1.0519773990790835)
#         Predict: 0.0
#        Else (feature 7650 > 1.0519773990790835)
#         Predict: 1.0
#       Else (feature 9928 > 2.4685840711071916)
#        Predict: 1.0
#     Else (feature 8092 > 2.4096925532789997)
#      Predict: 1.0
#   Tree 6 (weight 1.0):
#     If (feature 2605 <= 3.4878927024976134)
#      If (feature 1058 <= 2.612425107333082)
#       If (feature 6488 <= 2.4685840711071916)
#        If (feature 2294 <= 2.4685840711071916)
#         Predict: 0.0
#        Else (feature 2294 > 2.4685840711071916)
#         Predict: 1.0
#       Else (feature 6488 > 2.4685840711071916)
#        Predict: 1.0
#      Else (feature 1058 > 2.612425107333082)
#       Predict: 1.0
#     Else (feature 2605 > 3.4878927024976134)
#      Predict: 0.0
#   Tree 7 (weight 1.0):
#     If (feature 8904 <= 1.8422025868595076)
#      If (feature 2913 <= 2.0916981699190016)
#       Predict: 0.0
#      Else (feature 2913 > 2.0916981699190016)
#       Predict: 1.0
#     Else (feature 8904 > 1.8422025868595076)
#      If (feature 3792 <= 1.6515188085949557)
#       Predict: 0.0
#      Else (feature 3792 > 1.6515188085949557)
#       Predict: 1.0
#   Tree 8 (weight 1.0):
#     If (feature 817 <= 2.612425107333082)
#      If (feature 9686 <= 2.3874894996192246)
#       If (feature 6683 <= 2.535349767419453)
#        If (feature 6488 <= 2.4685840711071916)
#         Predict: 0.0
#        Else (feature 6488 > 2.4685840711071916)
#         Predict: 1.0
#       Else (feature 6683 > 2.535349767419453)
#        Predict: 1.0
#      Else (feature 9686 > 2.3874894996192246)
#       If (feature 1315 <= 2.612425107333082)
#        If (feature 6660 <= 1.9192779267731368)
#         Predict: 0.0
#        Else (feature 6660 > 1.9192779267731368)
#         Predict: 1.0
#       Else (feature 1315 > 2.612425107333082)
#        Predict: 0.0
#     Else (feature 817 > 2.612425107333082)
#      Predict: 1.0
#   Tree 9 (weight 1.0):
#     If (feature 5720 <= 2.612425107333082)
#      If (feature 1821 <= 1.8988669295130092)
#       If (feature 5663 <= 2.4685840711071916)
#        Predict: 0.0
#       Else (feature 5663 > 2.4685840711071916)
#        If (feature 3644 <= 2.612425107333082)
#         Predict: 1.0
#        Else (feature 3644 > 2.612425107333082)
#         Predict: 0.0
#      Else (feature 1821 > 1.8988669295130092)
#       Predict: 1.0
#     Else (feature 5720 > 2.612425107333082)
#      Predict: 0.0
#   Tree 10 (weight 1.0):
#     If (feature 5128 <= 7.606049302258359)
#      If (feature 4892 <= 1.9405577339825348)
#       If (feature 7083 <= 2.4685840711071916)
#        If (feature 6586 <= 7.405752213321575)
#         Predict: 0.0
#        Else (feature 6586 > 7.405752213321575)
#         Predict: 1.0
#       Else (feature 7083 > 2.4685840711071916)
#        Predict: 1.0
#      Else (feature 4892 > 1.9405577339825348)
#       Predict: 0.0
#     Else (feature 5128 > 7.606049302258359)
#      Predict: 1.0
#   Tree 11 (weight 1.0):
#     If (feature 8660 <= 2.535349767419453)
#      If (feature 6660 <= 1.9192779267731368)
#       If (feature 7405 <= 1.0483143790330471)
#        If (feature 7838 <= 2.4685840711071916)
#         Predict: 0.0
#        Else (feature 7838 > 2.4685840711071916)
#         Predict: 1.0
#       Else (feature 7405 > 1.0483143790330471)
#        Predict: 0.0
#      Else (feature 6660 > 1.9192779267731368)
#       Predict: 0.0
#     Else (feature 8660 > 2.535349767419453)
#      Predict: 0.0
#   Tree 12 (weight 1.0):
#     If (feature 7352 <= 2.1542797413960044)
#      If (feature 3546 <= 2.612425107333082)
#       If (feature 4504 <= 7.837275321999246)
#        If (feature 6863 <= 6.366031442481656)
#         Predict: 0.0
#        Else (feature 6863 > 6.366031442481656)
#         Predict: 1.0
#       Else (feature 4504 > 7.837275321999246)
#        Predict: 1.0
#      Else (feature 3546 > 2.612425107333082)
#       Predict: 1.0
#     Else (feature 7352 > 2.1542797413960044)
#      Predict: 0.0
#   Tree 13 (weight 1.0):
#     If (feature 6372 <= 4.656880017699109)
#      If (feature 5741 <= 6.586457623050844)
#       Predict: 0.0
#      Else (feature 5741 > 6.586457623050844)
#       If (feature 6586 <= 2.4685840711071916)
#        If (feature 7501 <= 2.612425107333082)
#         Predict: 0.0
#        Else (feature 7501 > 2.612425107333082)
#         Predict: 1.0
#       Else (feature 6586 > 2.4685840711071916)
#        Predict: 1.0
#     Else (feature 6372 > 4.656880017699109)
#      Predict: 0.0
#   Tree 14 (weight 1.0):
#     If (feature 2314 <= 5.06853528625175)
#      If (feature 3365 <= 2.4096925532789997)
#       If (feature 4344 <= 1.258400006781977)
#        If (feature 1217 <= 2.1887761771394803)
#         Predict: 0.0
#        Else (feature 1217 > 2.1887761771394803)
#         Predict: 1.0
#       Else (feature 4344 > 1.258400006781977)
#        If (feature 9240 <= 2.612425107333082)
#         Predict: 0.0
#        Else (feature 9240 > 2.612425107333082)
#         Predict: 1.0
#      Else (feature 3365 > 2.4096925532789997)
#       Predict: 1.0
#     Else (feature 2314 > 5.06853528625175)
#      Predict: 1.0
#   Tree 15 (weight 1.0):
#     If (feature 4320 <= 2.2658515170531093)
#      If (feature 2358 <= 7.837275321999246)
#       If (feature 4750 <= 2.535349767419453)
#        Predict: 0.0
#       Else (feature 4750 > 2.535349767419453)
#        Predict: 1.0
#      Else (feature 2358 > 7.837275321999246)
#       Predict: 1.0
#     Else (feature 4320 > 2.2658515170531093)
#      If (feature 7779 <= 1.616210024987979)
#       Predict: 0.0
#      Else (feature 7779 > 1.616210024987979)
#       Predict: 1.0
#   Tree 16 (weight 1.0):
#     If (feature 1821 <= 1.8988669295130092)
#      If (feature 8438 <= 2.4685840711071916)
#       If (feature 3824 <= 1.1062943195804813)
#        If (feature 8962 <= 2.010438705170114)
#         Predict: 0.0
#        Else (feature 8962 > 2.010438705170114)
#         Predict: 1.0
#       Else (feature 3824 > 1.1062943195804813)
#        If (feature 666 <= 2.4685840711071916)
#         Predict: 0.0
#        Else (feature 666 > 2.4685840711071916)
#         Predict: 1.0
#      Else (feature 8438 > 2.4685840711071916)
#       Predict: 0.0
#     Else (feature 1821 > 1.8988669295130092)
#      Predict: 0.0
#   Tree 17 (weight 1.0):
#     If (feature 5347 <= 2.535349767419453)
#      If (feature 9078 <= 2.612425107333082)
#       Predict: 0.0
#      Else (feature 9078 > 2.612425107333082)
#       If (feature 8430 <= 1.7306308112024027)
#        Predict: 1.0
#       Else (feature 8430 > 1.7306308112024027)
#        Predict: 0.0
#     Else (feature 5347 > 2.535349767419453)
#      Predict: 0.0
#   Tree 18 (weight 1.0):
#     If (feature 1626 <= 2.3570122954500867)
#      If (feature 1055 <= 2.612425107333082)
#       If (feature 7838 <= 7.405752213321575)
#        Predict: 0.0
#       Else (feature 7838 > 7.405752213321575)
#        Predict: 1.0
#      Else (feature 1055 > 2.612425107333082)
#       Predict: 0.0
#     Else (feature 1626 > 2.3570122954500867)
#      Predict: 1.0
#   Tree 19 (weight 1.0):
#     If (feature 2342 <= 7.2290776598369995)
#      If (feature 1299 <= 8.138416305827764)
#       If (feature 8786 <= 2.612425107333082)
#        Predict: 0.0
#       Else (feature 8786 > 2.612425107333082)
#        Predict: 1.0
#      Else (feature 1299 > 8.138416305827764)
#       Predict: 1.0
#     Else (feature 2342 > 7.2290776598369995)
#      Predict: 1.0
#   Tree 20 (weight 1.0):
#     Predict: 0.0
#   Tree 21 (weight 1.0):
#     If (feature 817 <= 2.612425107333082)
#      Predict: 0.0
#     Else (feature 817 > 2.612425107333082)
#      Predict: 1.0
#   Tree 22 (weight 1.0):
#     If (feature 6467 <= 3.5547457607309494)
#      If (feature 6512 <= 2.4685840711071916)
#       If (feature 9691 <= 2.535349767419453)
#        Predict: 0.0
#       Else (feature 9691 > 2.535349767419453)
#        Predict: 1.0
#      Else (feature 6512 > 2.4685840711071916)
#       Predict: 0.0
#     Else (feature 6467 > 3.5547457607309494)
#      If (feature 488 <= 0.521400036012479)
#       Predict: 0.0
#      Else (feature 488 > 0.521400036012479)
#       If (feature 1029 <= 2.612425107333082)
#        Predict: 0.0
#       Else (feature 1029 > 2.612425107333082)
#        Predict: 1.0
#   Tree 23 (weight 1.0):
#     If (feature 6206 <= 2.612425107333082)
#      If (feature 7969 <= 7.606049302258359)
#       If (feature 5169 <= 2.122010480827219)
#        Predict: 0.0
#       Else (feature 5169 > 2.122010480827219)
#        If (feature 8899 <= 1.4695361199942498)
#         Predict: 1.0
#        Else (feature 8899 > 1.4695361199942498)
#         Predict: 0.0
#      Else (feature 7969 > 7.606049302258359)
#       Predict: 1.0
#     Else (feature 6206 > 2.612425107333082)
#      Predict: 1.0
#   Tree 24 (weight 1.0):
#     If (feature 2663 <= 0.8492448450250014)
#      If (feature 2657 <= 2.3093572055479243)
#       If (feature 6749 <= 1.2753507826198178)
#        If (feature 6683 <= 2.535349767419453)
#         Predict: 0.0
#        Else (feature 6683 > 2.535349767419453)
#         Predict: 1.0
#       Else (feature 6749 > 1.2753507826198178)
#        Predict: 0.0
#      Else (feature 2657 > 2.3093572055479243)
#       Predict: 0.0
#     Else (feature 2663 > 0.8492448450250014)
#      If (feature 4683 <= 4.4342500100216995)
#       If (feature 3443 <= 2.3570122954500867)
#        If (feature 6197 <= 2.225830163216341)
#         Predict: 0.0
#        Else (feature 6197 > 2.225830163216341)
#         Predict: 1.0
#       Else (feature 3443 > 2.3570122954500867)
#        Predict: 1.0
#      Else (feature 4683 > 4.4342500100216995)
#       Predict: 1.0
#   Tree 25 (weight 1.0):
#     If (feature 4892 <= 1.9405577339825348)
#      If (feature 3507 <= 2.1887761771394803)
#       If (feature 8786 <= 2.612425107333082)
#        Predict: 0.0
#       Else (feature 8786 > 2.612425107333082)
#        Predict: 1.0
#      Else (feature 3507 > 2.1887761771394803)
#       Predict: 0.0
#     Else (feature 4892 > 1.9405577339825348)
#      Predict: 0.0
#   Tree 26 (weight 1.0):
#     If (feature 2360 <= 2.535349767419453)
#      Predict: 0.0
#     Else (feature 2360 > 2.535349767419453)
#      Predict: 1.0
#   Tree 27 (weight 1.0):
#     If (feature 267 <= 2.535349767419453)
#      Predict: 0.0
#     Else (feature 267 > 2.535349767419453)
#      Predict: 1.0
#   Tree 28 (weight 1.0):
#     If (feature 6659 <= 2.612425107333082)
#      If (feature 9240 <= 2.612425107333082)
#       If (feature 9223 <= 2.4096925532789997)
#        If (feature 9330 <= 2.4685840711071916)
#         Predict: 0.0
#        Else (feature 9330 > 2.4685840711071916)
#         Predict: 1.0
#       Else (feature 9223 > 2.4096925532789997)
#        Predict: 1.0
#      Else (feature 9240 > 2.612425107333082)
#       Predict: 1.0
#     Else (feature 6659 > 2.612425107333082)
#      Predict: 1.0
#   Tree 29 (weight 1.0):
#     If (feature 9472 <= 2.535349767419453)
#      If (feature 9162 <= 4.3342129482736915)
#       If (feature 1058 <= 7.837275321999246)
#        Predict: 0.0
#       Else (feature 1058 > 7.837275321999246)
#        Predict: 1.0
#      Else (feature 9162 > 4.3342129482736915)
#       If (feature 8904 <= 1.8422025868595076)
#        Predict: 0.0
#       Else (feature 8904 > 1.8422025868595076)
#        Predict: 1.0
#     Else (feature 9472 > 2.535349767419453)
#      Predict: 0.0
#   Tree 30 (weight 1.0):
#     If (feature 3919 <= 2.225830163216341)
#      If (feature 4495 <= 0.7700730659813543)
#       If (feature 493 <= 2.4096925532789997)
#        If (feature 5925 <= 2.3093572055479243)
#         Predict: 0.0
#        Else (feature 5925 > 2.3093572055479243)
#         Predict: 1.0
#       Else (feature 493 > 2.4096925532789997)
#        Predict: 0.0
#      Else (feature 4495 > 0.7700730659813543)
#       If (feature 5756 <= 6.9280716166437735)
#        Predict: 0.0
#       Else (feature 5756 > 6.9280716166437735)
#        Predict: 1.0
#     Else (feature 3919 > 2.225830163216341)
#      If (feature 6683 <= 2.535349767419453)
#       Predict: 0.0
#      Else (feature 6683 > 2.535349767419453)
#       Predict: 1.0
#   Tree 31 (weight 1.0):
#     If (feature 6369 <= 4.3342129482736915)
#      If (feature 7155 <= 2.4685840711071916)
#       If (feature 387 <= 7.405752213321575)
#        Predict: 0.0
#       Else (feature 387 > 7.405752213321575)
#        Predict: 1.0
#      Else (feature 7155 > 2.4685840711071916)
#       Predict: 1.0
#     Else (feature 6369 > 4.3342129482736915)
#      Predict: 0.0
#   Tree 32 (weight 1.0):
#     If (feature 1206 <= 2.612425107333082)
#      If (feature 6403 <= 1.1580646590509014)
#       If (feature 4037 <= 7.606049302258359)
#        Predict: 0.0
#       Else (feature 4037 > 7.606049302258359)
#        Predict: 1.0
#      Else (feature 6403 > 1.1580646590509014)
#       If (feature 4559 <= 1.4695361199942498)
#        If (feature 8092 <= 2.4096925532789997)
#         Predict: 0.0
#        Else (feature 8092 > 2.4096925532789997)
#         Predict: 1.0
#       Else (feature 4559 > 1.4695361199942498)
#        Predict: 0.0
#     Else (feature 1206 > 2.612425107333082)
#      Predict: 1.0
#   Tree 33 (weight 1.0):
#     If (feature 1041 <= 2.612425107333082)
#      If (feature 8344 <= 4.161878876045382)
#       If (feature 6791 <= 2.4096925532789997)
#        Predict: 0.0
#       Else (feature 6791 > 2.4096925532789997)
#        Predict: 1.0
#      Else (feature 8344 > 4.161878876045382)
#       Predict: 0.0
#     Else (feature 1041 > 2.612425107333082)
#      Predict: 0.0
#   Tree 34 (weight 1.0):
#     If (feature 4338 <= 5.876750614675155)
#      If (feature 3736 <= 2.4685840711071916)
#       If (feature 2722 <= 2.535349767419453)
#        If (feature 1678 <= 2.1542797413960044)
#         Predict: 0.0
#        Else (feature 1678 > 2.1542797413960044)
#         Predict: 1.0
#       Else (feature 2722 > 2.535349767419453)
#        If (feature 8381 <= 1.7913112397045365)
#         Predict: 0.0
#        Else (feature 8381 > 1.7913112397045365)
#         Predict: 1.0
#      Else (feature 3736 > 2.4685840711071916)
#       If (feature 3721 <= 0.8847928058668665)
#        Predict: 0.0
#       Else (feature 3721 > 0.8847928058668665)
#        Predict: 1.0
#     Else (feature 4338 > 5.876750614675155)
#      Predict: 1.0
#   Tree 35 (weight 1.0):
#     If (feature 1703 <= 2.4685840711071916)
#      If (feature 5034 <= 2.535349767419453)
#       Predict: 0.0
#      Else (feature 5034 > 2.535349767419453)
#       Predict: 1.0
#     Else (feature 1703 > 2.4685840711071916)
#      Predict: 0.0
#   Tree 36 (weight 1.0):
#     If (feature 8855 <= 3.2824439198878768)
#      If (feature 7895 <= 2.3093572055479243)
#       If (feature 9527 <= 1.6515188085949557)
#        Predict: 0.0
#       Else (feature 9527 > 1.6515188085949557)
#        If (feature 6168 <= 1.7306308112024027)
#         Predict: 0.0
#        Else (feature 6168 > 1.7306308112024027)
#         Predict: 1.0
#      Else (feature 7895 > 2.3093572055479243)
#       Predict: 0.0
#     Else (feature 8855 > 3.2824439198878768)
#      Predict: 1.0
#   Tree 37 (weight 1.0):
#     If (feature 1960 <= 2.225830163216341)
#      If (feature 5056 <= 1.8988669295130092)
#       Predict: 0.0
#      Else (feature 5056 > 1.8988669295130092)
#       If (feature 9126 <= 2.1887761771394803)
#        Predict: 0.0
#       Else (feature 9126 > 2.1887761771394803)
#        Predict: 1.0
#     Else (feature 1960 > 2.225830163216341)
#      If (feature 2309 <= 2.612425107333082)
#       Predict: 0.0
#      Else (feature 2309 > 2.612425107333082)
#       Predict: 1.0
#   Tree 38 (weight 1.0):
#     If (feature 5076 <= 1.4867792080298345)
#      If (feature 5440 <= 2.4685840711071916)
#       If (feature 3824 <= 1.1062943195804813)
#        If (feature 5925 <= 2.3093572055479243)
#         Predict: 0.0
#        Else (feature 5925 > 2.3093572055479243)
#         Predict: 1.0
#       Else (feature 3824 > 1.1062943195804813)
#        Predict: 0.0
#      Else (feature 5440 > 2.4685840711071916)
#       Predict: 0.0
#     Else (feature 5076 > 1.4867792080298345)
#      Predict: 0.0
#   Tree 39 (weight 1.0):
#     If (feature 5504 <= 2.535349767419453)
#      If (feature 7838 <= 7.405752213321575)
#       If (feature 9078 <= 2.612425107333082)
#        Predict: 0.0
#       Else (feature 9078 > 2.612425107333082)
#        Predict: 1.0
#      Else (feature 7838 > 7.405752213321575)
#       Predict: 1.0
#     Else (feature 5504 > 2.535349767419453)
#      Predict: 1.0
#   Tree 40 (weight 1.0):
#     If (feature 3340 <= 2.2658515170531093)
#      If (feature 4000 <= 2.4685840711071916)
#       If (feature 6048 <= 3.112450891927373)
#        If (feature 431 <= 5.526607760578523)
#         Predict: 0.0
#        Else (feature 431 > 5.526607760578523)
#         Predict: 1.0
#       Else (feature 6048 > 3.112450891927373)
#        Predict: 0.0
#      Else (feature 4000 > 2.4685840711071916)
#       If (feature 6451 <= 1.7913112397045365)
#        Predict: 0.0
#       Else (feature 6451 > 1.7913112397045365)
#        Predict: 1.0
#     Else (feature 3340 > 2.2658515170531093)
#      If (feature 6048 <= 1.0374836306424575)
#       If (feature 1634 <= 2.225830163216341)
#        If (feature 488 <= 0.521400036012479)
#         Predict: 1.0
#        Else (feature 488 > 0.521400036012479)
#         Predict: 0.0
#       Else (feature 1634 > 2.225830163216341)
#        Predict: 1.0
#      Else (feature 6048 > 1.0374836306424575)
#       Predict: 0.0
#   Tree 41 (weight 1.0):
#     If (feature 9162 <= 1.4447376494245638)
#      If (feature 9223 <= 2.4096925532789997)
#       If (feature 2622 <= 2.2658515170531093)
#        If (feature 2342 <= 2.4096925532789997)
#         Predict: 0.0
#        Else (feature 2342 > 2.4096925532789997)
#         Predict: 1.0
#       Else (feature 2622 > 2.2658515170531093)
#        If (feature 5925 <= 2.3093572055479243)
#         Predict: 0.0
#        Else (feature 5925 > 2.3093572055479243)
#         Predict: 1.0
#      Else (feature 9223 > 2.4096925532789997)
#       Predict: 1.0
#     Else (feature 9162 > 1.4447376494245638)
#      If (feature 1039 <= 2.612425107333082)
#       If (feature 6537 <= 1.7165453727190545)
#        If (feature 594 <= 1.9192779267731368)
#         Predict: 0.0
#        Else (feature 594 > 1.9192779267731368)
#         Predict: 1.0
#       Else (feature 6537 > 1.7165453727190545)
#        Predict: 0.0
#      Else (feature 1039 > 2.612425107333082)
#       Predict: 0.0
#   Tree 42 (weight 1.0):
#     If (feature 6501 <= 2.4096925532789997)
#      If (feature 4204 <= 6.462839224188013)
#       If (feature 666 <= 2.4685840711071916)
#        Predict: 0.0
#       Else (feature 666 > 2.4685840711071916)
#        Predict: 1.0
#      Else (feature 4204 > 6.462839224188013)
#       Predict: 1.0
#     Else (feature 6501 > 2.4096925532789997)
#      Predict: 0.0
#   Tree 43 (weight 1.0):
#     If (feature 6616 <= 2.3570122954500867)
#      If (feature 2540 <= 2.1887761771394803)
#       If (feature 2385 <= 2.225830163216341)
#        If (feature 9805 <= 4.7181130094794925)
#         Predict: 0.0
#        Else (feature 9805 > 4.7181130094794925)
#         Predict: 1.0
#       Else (feature 2385 > 2.225830163216341)
#        If (feature 6586 <= 2.4685840711071916)
#         Predict: 0.0
#        Else (feature 6586 > 2.4685840711071916)
#         Predict: 1.0
#      Else (feature 2540 > 2.1887761771394803)
#       Predict: 0.0
#     Else (feature 6616 > 2.3570122954500867)
#      Predict: 0.0
#   Tree 44 (weight 1.0):
#     If (feature 8438 <= 2.4685840711071916)
#      If (feature 3523 <= 5.06853528625175)
#       If (feature 5974 <= 2.535349767419453)
#        If (feature 5169 <= 2.122010480827219)
#         Predict: 0.0
#        Else (feature 5169 > 2.122010480827219)
#         Predict: 1.0
#       Else (feature 5974 > 2.535349767419453)
#        Predict: 1.0
#      Else (feature 3523 > 5.06853528625175)
#       Predict: 0.0
#     Else (feature 8438 > 2.4685840711071916)
#      Predict: 0.0
#   Tree 45 (weight 1.0):
#     If (feature 2715 <= 7.2290776598369995)
#      If (feature 7650 <= 1.0519773990790835)
#       If (feature 6048 <= 3.112450891927373)
#        If (feature 5891 <= 5.821673201947604)
#         Predict: 0.0
#        Else (feature 5891 > 5.821673201947604)
#         Predict: 1.0
#       Else (feature 6048 > 3.112450891927373)
#        Predict: 0.0
#      Else (feature 7650 > 1.0519773990790835)
#       Predict: 0.0
#     Else (feature 2715 > 7.2290776598369995)
#      Predict: 1.0
#   Tree 46 (weight 1.0):
#     If (feature 3048 <= 2.3570122954500867)
#      If (feature 8871 <= 2.0916981699190016)
#       If (feature 4750 <= 2.535349767419453)
#        If (feature 2314 <= 5.06853528625175)
#         Predict: 0.0
#        Else (feature 2314 > 5.06853528625175)
#         Predict: 1.0
#       Else (feature 4750 > 2.535349767419453)
#        If (feature 488 <= 0.521400036012479)
#         Predict: 1.0
#        Else (feature 488 > 0.521400036012479)
#         Predict: 0.0
#      Else (feature 8871 > 2.0916981699190016)
#       If (feature 2314 <= 1.6895117620839166)
#        Predict: 0.0
#       Else (feature 2314 > 1.6895117620839166)
#        Predict: 1.0
#     Else (feature 3048 > 2.3570122954500867)
#      Predict: 0.0
#   Tree 47 (weight 1.0):
#     If (feature 5128 <= 2.535349767419453)
#      If (feature 55 <= 2.3570122954500867)
#       Predict: 0.0
#      Else (feature 55 > 2.3570122954500867)
#       Predict: 1.0
#     Else (feature 5128 > 2.535349767419453)
#      If (feature 4495 <= 0.7700730659813543)
#       Predict: 0.0
#      Else (feature 4495 > 0.7700730659813543)
#       Predict: 1.0
#   Tree 48 (weight 1.0):
#     If (feature 7973 <= 2.3093572055479243)
#      If (feature 8904 <= 1.8422025868595076)
#       Predict: 0.0
#      Else (feature 8904 > 1.8422025868595076)
#       If (feature 1612 <= 2.612425107333082)
#        If (feature 4263 <= 1.363075121372914)
#         Predict: 0.0
#        Else (feature 4263 > 1.363075121372914)
#         Predict: 1.0
#       Else (feature 1612 > 2.612425107333082)
#        Predict: 0.0
#     Else (feature 7973 > 2.3093572055479243)
#      Predict: 0.0
#   Tree 49 (weight 1.0):
#     If (feature 6325 <= 2.612425107333082)
#      If (feature 817 <= 2.612425107333082)
#       If (feature 8790 <= 2.535349767419453)
#        If (feature 7939 <= 2.535349767419453)
#         Predict: 0.0
#        Else (feature 7939 > 2.535349767419453)
#         Predict: 1.0
#       Else (feature 8790 > 2.535349767419453)
#        Predict: 1.0
#      Else (feature 817 > 2.612425107333082)
#       Predict: 1.0
#     Else (feature 6325 > 2.612425107333082)
#      Predict: 1.0
#   Tree 50 (weight 1.0):
#     If (feature 6749 <= 1.2753507826198178)
#      Predict: 0.0
#     Else (feature 6749 > 1.2753507826198178)
#      If (feature 4293 <= 2.612425107333082)
#       If (feature 3010 <= 2.535349767419453)
#        Predict: 0.0
#       Else (feature 3010 > 2.535349767419453)
#        Predict: 1.0
#      Else (feature 4293 > 2.612425107333082)
#       Predict: 1.0
#   Tree 51 (weight 1.0):
#     If (feature 8790 <= 2.535349767419453)
#      If (feature 1485 <= 2.3093572055479243)
#       If (feature 2116 <= 6.031316115510342)
#        Predict: 0.0
#       Else (feature 2116 > 6.031316115510342)
#        Predict: 1.0
#      Else (feature 1485 > 2.3093572055479243)
#       If (feature 763 <= 1.0446779993685074)
#        Predict: 1.0
#       Else (feature 763 > 1.0446779993685074)
#        Predict: 0.0
#     Else (feature 8790 > 2.535349767419453)
#      If (feature 5741 <= 1.3172915246101689)
#       Predict: 1.0
#      Else (feature 5741 > 1.3172915246101689)
#       Predict: 0.0
#   Tree 52 (weight 1.0):
#     If (feature 690 <= 1.5832310410920802)
#      If (feature 7977 <= 2.535349767419453)
#       If (feature 3546 <= 2.612425107333082)
#        Predict: 0.0
#       Else (feature 3546 > 2.612425107333082)
#        Predict: 1.0
#      Else (feature 7977 > 2.535349767419453)
#       If (feature 8344 <= 0.8323757752090764)
#        Predict: 0.0
#       Else (feature 8344 > 0.8323757752090764)
#        Predict: 1.0
#     Else (feature 690 > 1.5832310410920802)
#      If (feature 9605 <= 2.1887761771394803)
#       If (feature 3479 <= 0.9676026594548781)
#        Predict: 0.0
#       Else (feature 3479 > 0.9676026594548781)
#        Predict: 1.0
#      Else (feature 9605 > 2.1887761771394803)
#       Predict: 0.0
#   Tree 53 (weight 1.0):
#     If (feature 7605 <= 2.4685840711071916)
#      If (feature 6142 <= 2.4685840711071916)
#       If (feature 9275 <= 2.612425107333082)
#        If (feature 55 <= 2.3570122954500867)
#         Predict: 0.0
#        Else (feature 55 > 2.3570122954500867)
#         Predict: 1.0
#       Else (feature 9275 > 2.612425107333082)
#        Predict: 1.0
#      Else (feature 6142 > 2.4685840711071916)
#       Predict: 0.0
#     Else (feature 7605 > 2.4685840711071916)
#      Predict: 0.0
#   Tree 54 (weight 1.0):
#     If (feature 9126 <= 2.1887761771394803)
#      Predict: 0.0
#     Else (feature 9126 > 2.1887761771394803)
#      Predict: 1.0
#   Tree 55 (weight 1.0):
#     If (feature 3674 <= 2.4685840711071916)
#      If (feature 1662 <= 2.535349767419453)
#       If (feature 1718 <= 5.821673201947604)
#        Predict: 0.0
#       Else (feature 1718 > 5.821673201947604)
#        Predict: 1.0
#      Else (feature 1662 > 2.535349767419453)
#       Predict: 1.0
#     Else (feature 3674 > 2.4685840711071916)
#      Predict: 0.0
#   Tree 56 (weight 1.0):
#     If (feature 1780 <= 2.3570122954500867)
#      If (feature 6501 <= 2.4096925532789997)
#       If (feature 4224 <= 5.696600788539028)
#        If (feature 3981 <= 2.535349767419453)
#         Predict: 0.0
#        Else (feature 3981 > 2.535349767419453)
#         Predict: 1.0
#       Else (feature 4224 > 5.696600788539028)
#        Predict: 1.0
#      Else (feature 6501 > 2.4096925532789997)
#       If (feature 9594 <= 2.4096925532789997)
#        If (feature 7405 <= 1.0483143790330471)
#         Predict: 0.0
#        Else (feature 7405 > 1.0483143790330471)
#         Predict: 1.0
#       Else (feature 9594 > 2.4096925532789997)
#        Predict: 1.0
#     Else (feature 1780 > 2.3570122954500867)
#      Predict: 0.0
#   Tree 57 (weight 1.0):
#     If (feature 5133 <= 1.5939841437025621)
#      If (feature 3824 <= 1.1062943195804813)
#       If (feature 2913 <= 2.0916981699190016)
#        Predict: 0.0
#       Else (feature 2913 > 2.0916981699190016)
#        If (feature 855 <= 1.807706151116032)
#         Predict: 1.0
#        Else (feature 855 > 1.807706151116032)
#         Predict: 0.0
#      Else (feature 3824 > 1.1062943195804813)
#       Predict: 0.0
#     Else (feature 5133 > 1.5939841437025621)
#      If (feature 8507 <= 2.225830163216341)
#       Predict: 0.0
#      Else (feature 8507 > 2.225830163216341)
#       Predict: 1.0
#   Tree 58 (weight 1.0):
#     If (feature 6044 <= 2.4685840711071916)
#      If (feature 2214 <= 2.4685840711071916)
#       If (feature 9147 <= 2.225830163216341)
#        If (feature 9691 <= 2.535349767419453)
#         Predict: 0.0
#        Else (feature 9691 > 2.535349767419453)
#         Predict: 1.0
#       Else (feature 9147 > 2.225830163216341)
#        Predict: 0.0
#      Else (feature 2214 > 2.4685840711071916)
#       Predict: 0.0
#     Else (feature 6044 > 2.4685840711071916)
#      Predict: 0.0
#   Tree 59 (weight 1.0):
#     If (feature 9240 <= 2.612425107333082)
#      If (feature 9426 <= 1.5423920255849466)
#       If (feature 3840 <= 13.022704862614615)
#        Predict: 0.0
#       Else (feature 3840 > 13.022704862614615)
#        Predict: 1.0
#      Else (feature 9426 > 1.5423920255849466)
#       If (feature 7352 <= 2.1542797413960044)
#        Predict: 0.0
#       Else (feature 7352 > 2.1542797413960044)
#        Predict: 1.0
#     Else (feature 9240 > 2.612425107333082)
#      If (feature 8643 <= 1.5138128186649724)
#       Predict: 1.0
#      Else (feature 8643 > 1.5138128186649724)
#       Predict: 0.0
#   Tree 60 (weight 1.0):
#     If (feature 4559 <= 7.347680599971249)
#      If (feature 6629 <= 1.5231588851710487)
#       If (feature 3549 <= 2.535349767419453)
#        Predict: 0.0
#       Else (feature 3549 > 2.535349767419453)
#        If (feature 1718 <= 1.9405577339825348)
#         Predict: 0.0
#        Else (feature 1718 > 1.9405577339825348)
#         Predict: 1.0
#      Else (feature 6629 > 1.5231588851710487)
#       If (feature 3704 <= 1.452867909860454)
#        If (feature 5581 <= 4.883114352300986)
#         Predict: 0.0
#        Else (feature 5581 > 4.883114352300986)
#         Predict: 1.0
#       Else (feature 3704 > 1.452867909860454)
#        Predict: 1.0
#     Else (feature 4559 > 7.347680599971249)
#      Predict: 1.0
#   Tree 61 (weight 1.0):
#     If (feature 8904 <= 1.8422025868595076)
#      If (feature 1611 <= 2.4096925532789997)
#       If (feature 6659 <= 2.612425107333082)
#        If (feature 5619 <= 2.4096925532789997)
#         Predict: 0.0
#        Else (feature 5619 > 2.4096925532789997)
#         Predict: 1.0
#       Else (feature 6659 > 2.612425107333082)
#        Predict: 1.0
#      Else (feature 1611 > 2.4096925532789997)
#       If (feature 8855 <= 1.094147973295959)
#        Predict: 0.0
#       Else (feature 8855 > 1.094147973295959)
#        Predict: 1.0
#     Else (feature 8904 > 1.8422025868595076)
#      If (feature 6406 <= 1.4611325608360592)
#       If (feature 2314 <= 1.6895117620839166)
#        If (feature 3944 <= 2.036085352363889)
#         Predict: 0.0
#        Else (feature 3944 > 2.036085352363889)
#         Predict: 1.0
#       Else (feature 2314 > 1.6895117620839166)
#        Predict: 1.0
#      Else (feature 6406 > 1.4611325608360592)
#       Predict: 1.0
#   Tree 62 (weight 1.0):
#     If (feature 1637 <= 2.3570122954500867)
#      If (feature 5974 <= 2.535349767419453)
#       If (feature 4495 <= 0.7700730659813543)
#        If (feature 5234 <= 2.612425107333082)
#         Predict: 0.0
#        Else (feature 5234 > 2.612425107333082)
#         Predict: 1.0
#       Else (feature 4495 > 0.7700730659813543)
#        If (feature 9398 <= 2.612425107333082)
#         Predict: 0.0
#        Else (feature 9398 > 2.612425107333082)
#         Predict: 1.0
#      Else (feature 5974 > 2.535349767419453)
#       Predict: 1.0
#     Else (feature 1637 > 2.3570122954500867)
#      If (feature 6749 <= 1.2753507826198178)
#       If (feature 1023 <= 2.612425107333082)
#        Predict: 0.0
#       Else (feature 1023 > 2.612425107333082)
#        Predict: 1.0
#      Else (feature 6749 > 1.2753507826198178)
#       Predict: 1.0
#   Tree 63 (weight 1.0):
#     If (feature 66 <= 1.7165453727190545)
#      Predict: 0.0
#     Else (feature 66 > 1.7165453727190545)
#      If (feature 9939 <= 2.225830163216341)
#       Predict: 0.0
#      Else (feature 9939 > 2.225830163216341)
#       Predict: 1.0
#   Tree 64 (weight 1.0):
#     If (feature 6659 <= 2.612425107333082)
#      Predict: 0.0
#     Else (feature 6659 > 2.612425107333082)
#      Predict: 1.0
#   Tree 65 (weight 1.0):
#     If (feature 2349 <= 2.612425107333082)
#      If (feature 2657 <= 2.3093572055479243)
#       If (feature 2402 <= 2.612425107333082)
#        Predict: 0.0
#       Else (feature 2402 > 2.612425107333082)
#        Predict: 1.0
#      Else (feature 2657 > 2.3093572055479243)
#       Predict: 0.0
#     Else (feature 2349 > 2.612425107333082)
#      If (feature 1698 <= 1.8988669295130092)
#       Predict: 1.0
#      Else (feature 1698 > 1.8988669295130092)
#       Predict: 0.0
#   Tree 66 (weight 1.0):
#     If (feature 817 <= 2.612425107333082)
#      If (feature 5216 <= 2.535349767419453)
#       If (feature 8410 <= 2.612425107333082)
#        If (feature 8438 <= 2.4685840711071916)
#         Predict: 0.0
#        Else (feature 8438 > 2.4685840711071916)
#         Predict: 1.0
#       Else (feature 8410 > 2.612425107333082)
#        Predict: 1.0
#      Else (feature 5216 > 2.535349767419453)
#       Predict: 0.0
#     Else (feature 817 > 2.612425107333082)
#      Predict: 0.0
#   Tree 67 (weight 1.0):
#     If (feature 8392 <= 2.3570122954500867)
#      If (feature 7155 <= 2.4685840711071916)
#       Predict: 0.0
#      Else (feature 7155 > 2.4685840711071916)
#       Predict: 1.0
#     Else (feature 8392 > 2.3570122954500867)
#      If (feature 6467 <= 0.7109491521461899)
#       Predict: 1.0
#      Else (feature 6467 > 0.7109491521461899)
#       Predict: 0.0
#   Tree 68 (weight 1.0):
#     If (feature 2349 <= 7.837275321999246)
#      If (feature 2589 <= 2.612425107333082)
#       If (feature 696 <= 2.535349767419453)
#        If (feature 5440 <= 2.4685840711071916)
#         Predict: 0.0
#        Else (feature 5440 > 2.4685840711071916)
#         Predict: 1.0
#       Else (feature 696 > 2.535349767419453)
#        Predict: 1.0
#      Else (feature 2589 > 2.612425107333082)
#       Predict: 1.0
#     Else (feature 2349 > 7.837275321999246)
#      Predict: 1.0
#   Tree 69 (weight 1.0):
#     If (feature 5581 <= 1.6277047841003285)
#      If (feature 4943 <= 1.9860436230853982)
#       If (feature 5169 <= 2.122010480827219)
#        If (feature 3840 <= 13.022704862614615)
#         Predict: 0.0
#        Else (feature 3840 > 13.022704862614615)
#         Predict: 1.0
#       Else (feature 5169 > 2.122010480827219)
#        Predict: 1.0
#      Else (feature 4943 > 1.9860436230853982)
#       If (feature 9614 <= 1.7165453727190545)
#        Predict: 0.0
#       Else (feature 9614 > 1.7165453727190545)
#        Predict: 1.0
#     Else (feature 5581 > 1.6277047841003285)
#      If (feature 2262 <= 1.745124579639029)
#       If (feature 7751 <= 1.4867792080298345)
#        If (feature 8786 <= 2.612425107333082)
#         Predict: 0.0
#        Else (feature 8786 > 2.612425107333082)
#         Predict: 1.0
#       Else (feature 7751 > 1.4867792080298345)
#        Predict: 0.0
#      Else (feature 2262 > 1.745124579639029)
#       Predict: 0.0
#   Tree 70 (weight 1.0):
#     If (feature 2309 <= 2.612425107333082)
#      If (feature 855 <= 1.807706151116032)
#       If (feature 6053 <= 2.4096925532789997)
#        Predict: 0.0
#       Else (feature 6053 > 2.4096925532789997)
#        If (feature 4338 <= 0.8395358020964506)
#         Predict: 0.0
#        Else (feature 4338 > 0.8395358020964506)
#         Predict: 1.0
#      Else (feature 855 > 1.807706151116032)
#       If (feature 5924 <= 1.572704336493164)
#        If (feature 8871 <= 2.0916981699190016)
#         Predict: 0.0
#        Else (feature 8871 > 2.0916981699190016)
#         Predict: 1.0
#       Else (feature 5924 > 1.572704336493164)
#        Predict: 0.0
#     Else (feature 2309 > 2.612425107333082)
#      Predict: 1.0
#   Tree 71 (weight 1.0):
#     If (feature 253 <= 2.3093572055479243)
#      If (feature 8092 <= 7.2290776598369995)
#       If (feature 3525 <= 1.9405577339825348)
#        Predict: 0.0
#       Else (feature 3525 > 1.9405577339825348)
#        If (feature 5349 <= 2.4096925532789997)
#         Predict: 0.0
#        Else (feature 5349 > 2.4096925532789997)
#         Predict: 1.0
#      Else (feature 8092 > 7.2290776598369995)
#       Predict: 1.0
#     Else (feature 253 > 2.3093572055479243)
#      Predict: 0.0
#   Tree 72 (weight 1.0):
#     If (feature 4338 <= 7.555822218868055)
#      If (feature 3935 <= 2.4685840711071916)
#       If (feature 5925 <= 2.3093572055479243)
#        Predict: 0.0
#       Else (feature 5925 > 2.3093572055479243)
#        Predict: 1.0
#      Else (feature 3935 > 2.4685840711071916)
#       Predict: 0.0
#     Else (feature 4338 > 7.555822218868055)
#      Predict: 1.0
#   Tree 73 (weight 1.0):
#     If (feature 5089 <= 2.612425107333082)
#      If (feature 6859 <= 2.4096925532789997)
#       Predict: 0.0
#      Else (feature 6859 > 2.4096925532789997)
#       Predict: 1.0
#     Else (feature 5089 > 2.612425107333082)
#      Predict: 0.0
#   Tree 74 (weight 1.0):
#     If (feature 2116 <= 6.031316115510342)
#      If (feature 7017 <= 2.612425107333082)
#       If (feature 763 <= 5.223389996842537)
#        Predict: 0.0
#       Else (feature 763 > 5.223389996842537)
#        Predict: 1.0
#      Else (feature 7017 > 2.612425107333082)
#       Predict: 1.0
#     Else (feature 2116 > 6.031316115510342)
#      Predict: 1.0
#   Tree 75 (weight 1.0):
#     If (feature 8566 <= 2.4685840711071916)
#      If (feature 3736 <= 2.4685840711071916)
#       Predict: 0.0
#      Else (feature 3736 > 2.4685840711071916)
#       If (feature 2262 <= 1.745124579639029)
#        Predict: 1.0
#       Else (feature 2262 > 1.745124579639029)
#        Predict: 0.0
#     Else (feature 8566 > 2.4685840711071916)
#      If (feature 2669 <= 1.7028458856249973)
#       Predict: 1.0
#      Else (feature 2669 > 1.7028458856249973)
#       Predict: 0.0
#   Tree 76 (weight 1.0):
#     If (feature 4344 <= 1.258400006781977)
#      If (feature 5029 <= 2.612425107333082)
#       If (feature 4559 <= 10.28675283995975)
#        If (feature 6859 <= 2.4096925532789997)
#         Predict: 0.0
#        Else (feature 6859 > 2.4096925532789997)
#         Predict: 1.0
#       Else (feature 4559 > 10.28675283995975)
#        Predict: 1.0
#      Else (feature 5029 > 2.612425107333082)
#       If (feature 4241 <= 2.4685840711071916)
#        If (feature 7751 <= 1.4867792080298345)
#         Predict: 1.0
#        Else (feature 7751 > 1.4867792080298345)
#         Predict: 0.0
#       Else (feature 4241 > 2.4685840711071916)
#        Predict: 0.0
#     Else (feature 4344 > 1.258400006781977)
#      Predict: 0.0
#   Tree 77 (weight 1.0):
#     If (feature 7017 <= 2.612425107333082)
#      If (feature 6282 <= 7.07103688635026)
#       If (feature 6487 <= 2.4096925532789997)
#        If (feature 7712 <= 5.526607760578523)
#         Predict: 0.0
#        Else (feature 7712 > 5.526607760578523)
#         Predict: 1.0
#       Else (feature 6487 > 2.4096925532789997)
#        If (feature 9785 <= 2.4096925532789997)
#         Predict: 0.0
#        Else (feature 9785 > 2.4096925532789997)
#         Predict: 1.0
#      Else (feature 6282 > 7.07103688635026)
#       Predict: 1.0
#     Else (feature 7017 > 2.612425107333082)
#      Predict: 1.0
#   Tree 78 (weight 1.0):
#     If (feature 3919 <= 2.225830163216341)
#      If (feature 4293 <= 2.612425107333082)
#       Predict: 0.0
#      Else (feature 4293 > 2.612425107333082)
#       Predict: 1.0
#     Else (feature 3919 > 2.225830163216341)
#      If (feature 7501 <= 2.612425107333082)
#       If (feature 1756 <= 0.7576757366747461)
#        Predict: 1.0
#       Else (feature 1756 > 0.7576757366747461)
#        Predict: 0.0
#      Else (feature 7501 > 2.612425107333082)
#       Predict: 1.0
#   Tree 79 (weight 1.0):
#     If (feature 5780 <= 2.535349767419453)
#      If (feature 5216 <= 2.535349767419453)
#       If (feature 1637 <= 2.3570122954500867)
#        If (feature 6586 <= 7.405752213321575)
#         Predict: 0.0
#        Else (feature 6586 > 7.405752213321575)
#         Predict: 1.0
#       Else (feature 1637 > 2.3570122954500867)
#        Predict: 1.0
#      Else (feature 5216 > 2.535349767419453)
#       Predict: 1.0
#     Else (feature 5780 > 2.535349767419453)
#      If (feature 4204 <= 6.462839224188013)
#       Predict: 0.0
#      Else (feature 4204 > 6.462839224188013)
#       Predict: 1.0
#   Tree 80 (weight 1.0):
#     If (feature 7061 <= 2.612425107333082)
#      If (feature 1637 <= 2.3570122954500867)
#       If (feature 2342 <= 2.4096925532789997)
#        Predict: 0.0
#       Else (feature 2342 > 2.4096925532789997)
#        If (feature 3781 <= 2.010438705170114)
#         Predict: 0.0
#        Else (feature 3781 > 2.010438705170114)
#         Predict: 1.0
#      Else (feature 1637 > 2.3570122954500867)
#       Predict: 1.0
#     Else (feature 7061 > 2.612425107333082)
#      If (feature 8344 <= 0.8323757752090764)
#       Predict: 1.0
#      Else (feature 8344 > 0.8323757752090764)
#       Predict: 0.0
#   Tree 81 (weight 1.0):
#     If (feature 7712 <= 5.526607760578523)
#      If (feature 132 <= 11.546786027739621)
#       If (feature 1751 <= 2.535349767419453)
#        Predict: 0.0
#       Else (feature 1751 > 2.535349767419453)
#        Predict: 1.0
#      Else (feature 132 > 11.546786027739621)
#       Predict: 1.0
#     Else (feature 7712 > 5.526607760578523)
#      Predict: 1.0
#   Tree 82 (weight 1.0):
#     If (feature 3045 <= 2.4685840711071916)
#      If (feature 9527 <= 4.954556425784867)
#       If (feature 3340 <= 2.2658515170531093)
#        If (feature 8312 <= 2.535349767419453)
#         Predict: 0.0
#        Else (feature 8312 > 2.535349767419453)
#         Predict: 1.0
#       Else (feature 3340 > 2.2658515170531093)
#        If (feature 3496 <= 2.3093572055479243)
#         Predict: 1.0
#        Else (feature 3496 > 2.3093572055479243)
#         Predict: 0.0
#      Else (feature 9527 > 4.954556425784867)
#       Predict: 1.0
#     Else (feature 3045 > 2.4685840711071916)
#      Predict: 1.0
#   Tree 83 (weight 1.0):
#     If (feature 1226 <= 4.009206393060802)
#      If (feature 1023 <= 2.612425107333082)
#       If (feature 4037 <= 7.606049302258359)
#        Predict: 0.0
#       Else (feature 4037 > 7.606049302258359)
#        Predict: 1.0
#      Else (feature 1023 > 2.612425107333082)
#       Predict: 1.0
#     Else (feature 1226 > 4.009206393060802)
#      Predict: 1.0
#   Tree 84 (weight 1.0):
#     If (feature 8159 <= 2.4685840711071916)
#      If (feature 8438 <= 2.4685840711071916)
#       If (feature 5756 <= 6.9280716166437735)
#        If (feature 5128 <= 7.606049302258359)
#         Predict: 0.0
#        Else (feature 5128 > 7.606049302258359)
#         Predict: 1.0
#       Else (feature 5756 > 6.9280716166437735)
#        Predict: 1.0
#      Else (feature 8438 > 2.4685840711071916)
#       If (feature 6240 <= 2.4096925532789997)
#        Predict: 1.0
#       Else (feature 6240 > 2.4096925532789997)
#        Predict: 0.0
#     Else (feature 8159 > 2.4685840711071916)
#      If (feature 2605 <= 1.1626309008325377)
#       Predict: 0.0
#      Else (feature 2605 > 1.1626309008325377)
#       Predict: 1.0
#   Tree 85 (weight 1.0):
#     If (feature 5133 <= 1.5939841437025621)
#      If (feature 7405 <= 1.0483143790330471)
#       If (feature 5214 <= 2.535349767419453)
#        If (feature 690 <= 4.7496931232762405)
#         Predict: 0.0
#        Else (feature 690 > 4.7496931232762405)
#         Predict: 1.0
#       Else (feature 5214 > 2.535349767419453)
#        Predict: 0.0
#      Else (feature 7405 > 1.0483143790330471)
#       If (feature 6053 <= 2.4096925532789997)
#        Predict: 0.0
#       Else (feature 6053 > 2.4096925532789997)
#        Predict: 1.0
#     Else (feature 5133 > 1.5939841437025621)
#      If (feature 1678 <= 2.1542797413960044)
#       Predict: 0.0
#      Else (feature 1678 > 2.1542797413960044)
#       Predict: 1.0
#   Tree 86 (weight 1.0):
#     If (feature 6537 <= 5.149636118157163)
#      If (feature 6148 <= 2.4096925532789997)
#       If (feature 8307 <= 7.07103688635026)
#        Predict: 0.0
#       Else (feature 8307 > 7.07103688635026)
#        Predict: 1.0
#      Else (feature 6148 > 2.4096925532789997)
#       Predict: 0.0
#     Else (feature 6537 > 5.149636118157163)
#      Predict: 0.0
#   Tree 87 (weight 1.0):
#     If (feature 4748 <= 1.9627836152679516)
#      If (feature 8392 <= 2.3570122954500867)
#       If (feature 3666 <= 2.535349767419453)
#        Predict: 0.0
#       Else (feature 3666 > 2.535349767419453)
#        Predict: 1.0
#      Else (feature 8392 > 2.3570122954500867)
#       Predict: 1.0
#     Else (feature 4748 > 1.9627836152679516)
#      Predict: 0.0
#   Tree 88 (weight 1.0):
#     If (feature 8925 <= 2.612425107333082)
#      If (feature 8490 <= 1.7165453727190545)
#       If (feature 8507 <= 2.225830163216341)
#        If (feature 6586 <= 2.4685840711071916)
#         Predict: 0.0
#        Else (feature 6586 > 2.4685840711071916)
#         Predict: 1.0
#       Else (feature 8507 > 2.225830163216341)
#        Predict: 0.0
#      Else (feature 8490 > 1.7165453727190545)
#       If (feature 1299 <= 1.1626309008325377)
#        Predict: 0.0
#       Else (feature 1299 > 1.1626309008325377)
#        Predict: 1.0
#     Else (feature 8925 > 2.612425107333082)
#      Predict: 0.0
#   Tree 89 (weight 1.0):
#     If (feature 9078 <= 2.612425107333082)
#      If (feature 392 <= 2.4685840711071916)
#       If (feature 3739 <= 1.9627836152679516)
#        If (feature 3998 <= 2.4685840711071916)
#         Predict: 0.0
#        Else (feature 3998 > 2.4685840711071916)
#         Predict: 1.0
#       Else (feature 3739 > 1.9627836152679516)
#        Predict: 0.0
#      Else (feature 392 > 2.4685840711071916)
#       Predict: 0.0
#     Else (feature 9078 > 2.612425107333082)
#      If (feature 6526 <= 1.4447376494245638)
#       If (feature 1770 <= 1.7306308112024027)
#        Predict: 1.0
#       Else (feature 1770 > 1.7306308112024027)
#        Predict: 0.0
#      Else (feature 6526 > 1.4447376494245638)
#       Predict: 0.0
#   Tree 90 (weight 1.0):
#     If (feature 9541 <= 1.7913112397045365)
#      If (feature 7741 <= 2.535349767419453)
#       If (feature 9797 <= 2.535349767419453)
#        If (feature 8568 <= 2.535349767419453)
#         Predict: 0.0
#        Else (feature 8568 > 2.535349767419453)
#         Predict: 1.0
#       Else (feature 9797 > 2.535349767419453)
#        Predict: 1.0
#      Else (feature 7741 > 2.535349767419453)
#       Predict: 1.0
#     Else (feature 9541 > 1.7913112397045365)
#      Predict: 0.0
#   Tree 91 (weight 1.0):
#     If (feature 1182 <= 2.535349767419453)
#      If (feature 5019 <= 2.612425107333082)
#       If (feature 6782 <= 2.4096925532789997)
#        If (feature 9797 <= 2.535349767419453)
#         Predict: 0.0
#        Else (feature 9797 > 2.535349767419453)
#         Predict: 1.0
#       Else (feature 6782 > 2.4096925532789997)
#        Predict: 1.0
#      Else (feature 5019 > 2.612425107333082)
#       If (feature 6403 <= 1.1580646590509014)
#        Predict: 0.0
#       Else (feature 6403 > 1.1580646590509014)
#        Predict: 1.0
#     Else (feature 1182 > 2.535349767419453)
#      Predict: 0.0
#   Tree 92 (weight 1.0):
#     If (feature 1058 <= 2.612425107333082)
#      If (feature 6053 <= 2.4096925532789997)
#       If (feature 2349 <= 2.612425107333082)
#        Predict: 0.0
#       Else (feature 2349 > 2.612425107333082)
#        Predict: 1.0
#      Else (feature 6053 > 2.4096925532789997)
#       Predict: 0.0
#     Else (feature 1058 > 2.612425107333082)
#      Predict: 1.0
#   Tree 93 (weight 1.0):
#     If (feature 6287 <= 1.9192779267731368)
#      If (feature 3261 <= 1.4956289965795349)
#       If (feature 9330 <= 2.4685840711071916)
#        If (feature 2342 <= 2.4096925532789997)
#         Predict: 0.0
#        Else (feature 2342 > 2.4096925532789997)
#         Predict: 1.0
#       Else (feature 9330 > 2.4685840711071916)
#        Predict: 1.0
#      Else (feature 3261 > 1.4956289965795349)
#       Predict: 0.0
#     Else (feature 6287 > 1.9192779267731368)
#      If (feature 3704 <= 1.452867909860454)
#       Predict: 0.0
#      Else (feature 3704 > 1.452867909860454)
#       Predict: 1.0
#   Tree 94 (weight 1.0):
#     If (feature 4416 <= 2.1887761771394803)
#      If (feature 2669 <= 5.108537656874992)
#       If (feature 8392 <= 2.3570122954500867)
#        If (feature 9078 <= 2.612425107333082)
#         Predict: 0.0
#        Else (feature 9078 > 2.612425107333082)
#         Predict: 1.0
#       Else (feature 8392 > 2.3570122954500867)
#        If (feature 4032 <= 1.5939841437025621)
#         Predict: 1.0
#        Else (feature 4032 > 1.5939841437025621)
#         Predict: 0.0
#      Else (feature 2669 > 5.108537656874992)
#       Predict: 1.0
#     Else (feature 4416 > 2.1887761771394803)
#      Predict: 0.0
#   Tree 95 (weight 1.0):
#     If (feature 9223 <= 2.4096925532789997)
#      If (feature 1029 <= 2.612425107333082)
#       If (feature 5374 <= 2.3570122954500867)
#        Predict: 0.0
#       Else (feature 5374 > 2.3570122954500867)
#        Predict: 1.0
#      Else (feature 1029 > 2.612425107333082)
#       Predict: 1.0
#     Else (feature 9223 > 2.4096925532789997)
#      Predict: 0.0
#   Tree 96 (weight 1.0):
#     If (feature 3704 <= 1.452867909860454)
#      If (feature 6749 <= 1.2753507826198178)
#       Predict: 0.0
#      Else (feature 6749 > 1.2753507826198178)
#       If (feature 9012 <= 2.612425107333082)
#        If (feature 5924 <= 1.572704336493164)
#         Predict: 0.0
#        Else (feature 5924 > 1.572704336493164)
#         Predict: 1.0
#       Else (feature 9012 > 2.612425107333082)
#        Predict: 1.0
#     Else (feature 3704 > 1.452867909860454)
#      If (feature 8267 <= 2.1542797413960044)
#       If (feature 4241 <= 2.4685840711071916)
#        If (feature 4320 <= 2.2658515170531093)
#         Predict: 0.0
#        Else (feature 4320 > 2.2658515170531093)
#         Predict: 1.0
#       Else (feature 4241 > 2.4685840711071916)
#        Predict: 0.0
#      Else (feature 8267 > 2.1542797413960044)
#       Predict: 1.0
#   Tree 97 (weight 1.0):
#     If (feature 3261 <= 1.4956289965795349)
#      If (feature 5133 <= 1.5939841437025621)
#       If (feature 5504 <= 2.535349767419453)
#        Predict: 0.0
#       Else (feature 5504 > 2.535349767419453)
#        Predict: 1.0
#      Else (feature 5133 > 1.5939841437025621)
#       If (feature 6010 <= 1.8422025868595076)
#        Predict: 0.0
#       Else (feature 6010 > 1.8422025868595076)
#        Predict: 1.0
#     Else (feature 3261 > 1.4956289965795349)
#      Predict: 0.0
#   Tree 98 (weight 1.0):
#     If (feature 763 <= 7.312745995579552)
#      Predict: 0.0
#     Else (feature 763 > 7.312745995579552)
#      Predict: 1.0
#   Tree 99 (weight 1.0):
#     If (feature 5440 <= 2.4685840711071916)
#      If (feature 9391 <= 1.9860436230853982)
#       Predict: 0.0
#      Else (feature 9391 > 1.9860436230853982)
#       If (feature 6403 <= 1.1580646590509014)
#        Predict: 0.0
#       Else (feature 6403 > 1.1580646590509014)
#        Predict: 1.0
#     Else (feature 5440 > 2.4685840711071916)
#      Predict: 1.0

# %%
# Stop the Spark session
spark.stop()
